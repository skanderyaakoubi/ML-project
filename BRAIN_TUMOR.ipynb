# %% [markdown]
# <a href="https://colab.research.google.com/github/skanderyaakoubi/ML-project/blob/main/BRAIN_TUMOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kKMKDu1CyhMFxvavQ9E7")
project = rf.workspace("iotseecs").project("brain-tumor-yzzav")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to BRAIN-TUMOR-1 in yolov11:: 100%|██████████| 1680/1680 [00:00<00:00, 3913.89it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.0/883.0 kB 19.2 MB/s eta 0:00:00
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n-seg.pt")
# Out:
# ...
# 100%|██████████| 5.90M/5.90M [00:00<00:00, 114MB/s]

# %%
model.train(data="/content/BRAIN-TUMOR-1/data.yaml", epochs=20, imgsz=640)
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model= YOLO("/content/runs/segment/train2/weights/best.pt")

# %%
result = model("/content/BRAIN-TUMOR-1/test/images/y154_jpg.rf.bcc8bca03d5c754b1c3fecab26584b79.jpg")
# Out:
# image 1/1 /content/BRAIN-TUMOR-1/test/images/y154_jpg.rf.bcc8bca03d5c754b1c3fecab26584b79.jpg: 640x640 1 tumor, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
result = model("/content/BRAIN-TUMOR-1/test/images/y193_jpg.rf.898204dcdfcff60fff55f3734567e205.jpg")
result[0].show()
# Out:
# image 1/1 /content/BRAIN-TUMOR-1/test/images/y193_jpg.rf.898204dcdfcff60fff55f3734567e205.jpg: 640x640 1 tumor, 40.3ms
# Speed: 7.3ms preprocess, 40.3ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
